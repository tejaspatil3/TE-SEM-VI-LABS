# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('https://gist.githubusercontent.com/curran/a08a1080b88344b0c8a7/raw/0e7a9b0a5d22642a06d3d5b9bcbad9890c8ee534/iris.csv')
data
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
data.isnull().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
data.dtypes
# Out:
# sepal_length    float64
# sepal_width     float64
# petal_length    float64
# petal_width     float64
# species          object
# dtype: object

# %%
sns.histplot(x = data['sepal_length'], kde=True)
# Out:
# <Axes: xlabel='sepal_length', ylabel='Count'>

# %%
sns.histplot(x = data['sepal_width'], kde=True)
# Out:
# <Axes: xlabel='sepal_width', ylabel='Count'>

# %%
sns.histplot(x = data['petal_length'], kde=True)
# Out:
# <Axes: xlabel='petal_length', ylabel='Count'>

# %%
sns.histplot(x = data['petal_width'], kde=True)
# Out:
# <Axes: xlabel='petal_width', ylabel='Count'>

# %%
sns.boxplot(data['sepal_length'])
# Out:
# <Axes: ylabel='sepal_length'>

# %%
sns.boxplot(data['sepal_width'])
# Out:
# <Axes: ylabel='sepal_width'>

# %%
sns.boxplot(data['petal_length'])
# Out:
# <Axes: ylabel='petal_length'>

# %%
sns.boxplot(data['petal_width'])
# Out:
# <Axes: ylabel='petal_width'>

# %%
sns.boxplot(x='petal_length',y='species',data=data, palette='Set2')
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_10496\455771820.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='petal_length',y='species',data=data, palette='Set2')
# <Axes: xlabel='petal_length', ylabel='species'>

# %%
sns.boxplot(x='sepal_length',y='species',data=data,palette='Set2')
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_10496\3413115332.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='sepal_length',y='species',data=data,palette='Set2')
# <Axes: xlabel='sepal_length', ylabel='species'>
