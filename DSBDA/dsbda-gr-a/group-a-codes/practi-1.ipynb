# %%
# 1

# !pip install numpy==1.26.4
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("C:/Users/Lenovo/Desktop/VSC1/dsbda-gr-a/DSBDA-yash/dataset/Iris.csv")

# %%
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df.head(10)
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa
# 5   6            5.4           3.9            1.7           0.4  Iris-setosa
# 6   7            4.6           3.4            1.4           0.3  Iris-setosa
# 7   8            5.0           3.4            1.5           0.2  Iris-setosa
# 8   9            4.4           2.9            1.4           0.2  Iris-setosa
# 9  10            4.9           3.1            1.5           0.1  Iris-setosa

# %%
df.tail()
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica

# %%
df.tail(10)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 140  141            6.7           3.1            5.6           2.4
# 141  142            6.9           3.1            5.1           2.3
# 142  143            5.8           2.7            5.1           1.9
# 143  144            6.8           3.2            5.9           2.3
# 144  145            6.7           3.3            5.7           2.5
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 140  Iris-virginica
# 141  Iris-virginica
# 142  Iris-virginica
# 143  Iris-virginica
# 144  Iris-virginica
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# ...

# %%
df.dtypes
# Out:
# Id                 int64
# SepalLengthCm    float64
# SepalWidthCm     float64
# PetalLengthCm    float64
# PetalWidthCm     float64
# Species           object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
df.shape
# Out:
# (150, 6)

# %%
df['Species'] = df['Species'].astype('category')

# %%
df.dtypes
# Out:
# Id                  int64
# SepalLengthCm     float64
# SepalWidthCm      float64
# PetalLengthCm     float64
# PetalWidthCm      float64
# Species          category
# dtype: object

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df['Species-encoded'] = le.fit_transform(df['Species'])

# %%
label_mapper = dict(zip(le.classes_,le.transform(le.classes_)))
label_mapper
# Out:
# {'Iris-setosa': 0, 'Iris-versicolor': 1, 'Iris-virginica': 2}

# %%
df[['Species', 'Species-encoded']].head()
# Out:
#        Species  Species-encoded
# 0  Iris-setosa                0
# 1  Iris-setosa                0
# 2  Iris-setosa                0
# 3  Iris-setosa                0
# 4  Iris-setosa                0

# %%
df[['Species', 'Species-encoded']].tail(53)
# Out:
#              Species  Species-encoded
# 97   Iris-versicolor                1
# 98   Iris-versicolor                1
# 99   Iris-versicolor                1
# 100   Iris-virginica                2
# 101   Iris-virginica                2
# 102   Iris-virginica                2
# 103   Iris-virginica                2
# 104   Iris-virginica                2
# 105   Iris-virginica                2
# 106   Iris-virginica                2
# 107   Iris-virginica                2
# 108   Iris-virginica                2
# 109   Iris-virginica                2
# 110   Iris-virginica                2
# 111   Iris-virginica                2
# 112   Iris-virginica                2
# 113   Iris-virginica                2
# 114   Iris-virginica                2
# 115   Iris-virginica                2
# 116   Iris-virginica                2
# 117   Iris-virginica                2
# 118   Iris-virginica                2
# 119   Iris-virginica                2
# 120   Iris-virginica                2
# ...

# %%
le.classes_
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
label_mapper = (zip(le.classes_,le.transform(le.classes_)))

# %%
le.classes_
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
dict(label_mapper)
# Out:
# {'Iris-setosa': 0, 'Iris-versicolor': 1, 'Iris-virginica': 2}

# %%
le.classes_
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)
