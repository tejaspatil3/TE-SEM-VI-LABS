# %%
# 2

# !pip install numpy==1.26.4

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('C:/Users/Lenovo/Desktop/VSC1/dsbda-gr-a/DSBDA-yash/dataset/acdemic_data.csv')

# %%
df
# Out:
#    Firstname Lastname Gender   SPOS DSBDA     WT   DA
# 0         LA      Roy      M   85.0    88   90.0   92
# 1         SA    Dixit      F   90.0    90   94.0   95
# 2         AB   Danial      M    NaN    na  100.0   80
# 3         DA   Kapoor      M   95.0    86  500.0   82
# 4         SA      Jha      F    NaN    84   98.0   84
# 5         WS   Thakur      F   87.0   NaN   97.0   86
# 6         DY   Kapoor      M   81.0    80   96.0   89
# 7         JK   Khanna      F   40.0    88   95.0   87
# 8         RT  Pardesi      M   10.0    96   94.0   88
# 9         UV  Pardesi      M    9.0   NaN   93.0   96
# 10        MN    Desai      F  200.0    87    NaN  N.A
# 11        BC    Patel      F  300.0   NaN   88.0  300

# %%
df.head()
# Out:
#   Firstname Lastname Gender  SPOS DSBDA     WT  DA
# 0        LA      Roy      M  85.0    88   90.0  92
# 1        SA    Dixit      F  90.0    90   94.0  95
# 2        AB   Danial      M   NaN    na  100.0  80
# 3        DA   Kapoor      M  95.0    86  500.0  82
# 4        SA      Jha      F   NaN    84   98.0  84

# %%
df.tail()
# Out:
#    Firstname Lastname Gender   SPOS DSBDA    WT   DA
# 7         JK   Khanna      F   40.0    88  95.0   87
# 8         RT  Pardesi      M   10.0    96  94.0   88
# 9         UV  Pardesi      M    9.0   NaN  93.0   96
# 10        MN    Desai      F  200.0    87   NaN  N.A
# 11        BC    Patel      F  300.0   NaN  88.0  300

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Firstname  12 non-null     object
#  1   Lastname   12 non-null     object
#  2   Gender     12 non-null     object
#  3   SPOS       10 non-null     float64
#  4   DSBDA      9 non-null      object
#  5   WT         11 non-null     float64
#  6   DA         12 non-null     object
# dtypes: float64(2), object(5)
# memory usage: 804.0+ bytes

# %%
df.shape
# Out:
# (12, 7)

# %%
df.isnull().sum()
# Out:
# Firstname    0
# Lastname     0
# Gender       0
# SPOS         2
# DSBDA        3
# WT           1
# DA           0
# dtype: int64

# %%
df.dtypes
# Out:
# Firstname     object
# Lastname      object
# Gender        object
# SPOS         float64
# DSBDA         object
# WT           float64
# DA            object
# dtype: object

# %%
df.replace('na,NA,N/A,n/a',np.nan,inplace = True)

# %%
df.replace('na',np.nan,inplace = True)

# %%
df.replace('N.A',np.nan,inplace = True)

# %% [markdown]
# dsbda to numeric

# %%
df[['SPOS', 'DSBDA', 'WT', 'DA']] = df[['SPOS', 'DSBDA', 'WT', 'DA']].apply(pd.to_numeric)

# %%
df.dtypes
# Out:
# Firstname     object
# Lastname      object
# Gender        object
# SPOS         float64
# DSBDA        float64
# WT           float64
# DA           float64
# dtype: object

# %%
spos_mean = df['SPOS'].mean()

# %%
spos_mean
# Out:
# 99.7

# %%
df['SPOS'] = df['SPOS'].fillna(df['SPOS'].mean())

# %%
df['DA'] = df['SPOS'].fillna(df['DA'].mean())
df['DSBDA'] = df['DSBDA'].fillna(df['DSBDA'].mean())
df['WT'] = df['WT'].fillna(df['WT'].mean())

# %%
df.isnull().sum()
# Out:
# Firstname    0
# Lastname     0
# Gender       0
# SPOS         0
# DSBDA        0
# WT           0
# DA           0
# dtype: int64

# %%
df
# Out:
#    Firstname Lastname Gender   SPOS   DSBDA          WT     DA
# 0         LA      Roy      M   85.0  88.000   90.000000   85.0
# 1         SA    Dixit      F   90.0  90.000   94.000000   90.0
# 2         AB   Danial      M   99.7  87.375  100.000000   99.7
# 3         DA   Kapoor      M   95.0  86.000  500.000000   95.0
# 4         SA      Jha      F   99.7  84.000   98.000000   99.7
# 5         WS   Thakur      F   87.0  87.375   97.000000   87.0
# 6         DY   Kapoor      M   81.0  80.000   96.000000   81.0
# 7         JK   Khanna      F   40.0  88.000   95.000000   40.0
# 8         RT  Pardesi      M   10.0  96.000   94.000000   10.0
# 9         UV  Pardesi      M    9.0  87.375   93.000000    9.0
# 10        MN    Desai      F  200.0  87.000  131.363636  200.0
# 11        BC    Patel      F  300.0  87.375   88.000000  300.0

# %%
df
# Out:
#    Firstname Lastname Gender   SPOS   DSBDA          WT     DA
# 0         LA      Roy      M   85.0  88.000   90.000000   85.0
# 1         SA    Dixit      F   90.0  90.000   94.000000   90.0
# 2         AB   Danial      M   99.7  87.375  100.000000   99.7
# 3         DA   Kapoor      M   95.0  86.000  500.000000   95.0
# 4         SA      Jha      F   99.7  84.000   98.000000   99.7
# 5         WS   Thakur      F   87.0  87.375   97.000000   87.0
# 6         DY   Kapoor      M   81.0  80.000   96.000000   81.0
# 7         JK   Khanna      F   40.0  88.000   95.000000   40.0
# 8         RT  Pardesi      M   10.0  96.000   94.000000   10.0
# 9         UV  Pardesi      M    9.0  87.375   93.000000    9.0
# 10        MN    Desai      F  200.0  87.000  131.363636  200.0
# 11        BC    Patel      F  300.0  87.375   88.000000  300.0

# %%
# # We use method = 'bfill’ for taking values from the next row. 
# df['SPOS'].fillna(method='bfill', inplace=True) 
# print(df['SPOS'].head(10))

# %%
# #Replacing Null with the value from the previous row or the next row 
# #method = 'pad’ for taking values from the previous row 

# df['DSBDA'].fillna(method='pad', inplace=True)
# print(df['DSBDA'].head(10))

# %%
# # How to remove rows with missing values

# # drop all rows with Null values 
# df.dropna(axis=0,inplace=True)

# %%
# # drop all rows with all null
# new_df = df.dropna(axis = 0, how ='all')

# # drop all rows with atleast one null
# new_df = df.dropna(axis = 0, how ='any')

# %%
# # drop all columns with all Null 
# new_df = df.dropna(axis = 1, how ='all')

# # drop all columns with atleast one Null
# new_df = df.dropna(axis = 1, how ='any')

# df.dropna()   # drops any row with at least 1 NaN

# df.dropna(axis=1)

# %%
# df.replace(["na", "Na", "NA", "n/a", "N/A", "", "missing"], pd.NA, inplace=True)

# df.replace('na', np.nan)  # replace 'na' text with real NaN
# df.replace(0, 100)        # replace 0 with 100

# %%
def detect_outliers_iqr(column):
    Q1 = column.quantile(0.25)
    Q3 = column.quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    return column[(column < lower_bound) | (column > upper_bound)]
    
for col in ['SPOS', 'DSBDA', 'WT', 'DA']:
    outliers = detect_outliers_iqr(df[col])
    print(f"Outliers in {col}:", outliers.tolist())
# Out:
# Outliers in SPOS: [10.0, 9.0, 200.0, 300.0]
# Outliers in DSBDA: [90.0, 84.0, 80.0, 96.0]
# Outliers in WT: [500.0, 131.36363636363637]
# Outliers in DA: [10.0, 9.0, 200.0, 300.0]

# %%
import matplotlib.pyplot as plt

# %%
# plt.boxplot(x=df['SPOS'])

# %%
plt.figure(figsize=(15, 15))  # Optional: Adjust figure size for better readability
plt.boxplot([df['SPOS'], df['DSBDA'], df['DA'], df['WT']], tick_labels=['SPOS', 'DSBDA', 'DA', 'WT'])
plt.title('Combined Box Plot of SPOS, DSBDA, DA, and WT')
plt.xlabel('Features')
plt.ylabel('Values')
plt.grid(True, linestyle='--', alpha=0.6) # Optional: Add a grid for better visualization
plt.show()

# %%
# Replace outliers with median (robust method)
for col in ['SPOS', 'DSBDA', 'WT', 'DA']:
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1
    lower = Q1 - 1.5 * IQR
    upper = Q3 + 1.5 * IQR
    median = df[col].median()
    df[col] = np.where((df[col] < lower) | (df[col] > upper), median, df[col])

# %%
def detect_outliers_iqr(column):
    Q1 = column.quantile(0.25)
    Q3 = column.quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    return column[(column < lower_bound) | (column > upper_bound)]
    
for col in ['SPOS', 'DSBDA', 'WT', 'DA']:
    outliers = detect_outliers_iqr(df[col])
    print(f"Outliers in {col}:", outliers.tolist())
# Out:
# Outliers in SPOS: [99.7, 99.7, 40.0]
# Outliers in DSBDA: [88.0, 86.0, 88.0, 87.0]
# Outliers in WT: [88.0]
# Outliers in DA: [99.7, 99.7, 40.0]

# %%
plt.figure(figsize=(15, 15))  # Optional: Adjust figure size for better readability
plt.boxplot([df['SPOS'], df['DSBDA'], df['DA'], df['WT']], tick_labels=['SPOS', 'DSBDA', 'DA', 'WT'])
plt.title('Combined Box Plot of SPOS, DSBDA, DA, and WT')
plt.xlabel('Features')
plt.ylabel('Values')
plt.grid(True, linestyle='--', alpha=0.6) # Optional: Add a grid for better visualization
plt.show()
